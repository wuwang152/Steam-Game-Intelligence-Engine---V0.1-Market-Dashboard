# %% [markdown]
# # Steam Data Audit (V0.1)
# Initial checks for schema, nulls, and distributions.

# %%
import pandas as pd
from pathlib import Path
raw_path = Path('..') / 'data' / 'raw' / 'steam_games.csv'
df = pd.read_csv(raw_path)
df.head()

# %%
df.info()

# %%
df.isna().mean().sort_values(ascending=False).head(20)

# %%
numeric_cols = ['Price', 'Peak CCU', 'Positive', 'Negative']
df[numeric_cols].describe().T
